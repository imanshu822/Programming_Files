# %%
pip install deepface
# Out:
# ...
#      |████████████████████████████████| 62 kB 851 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.3 MB 3.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 46.0 MB 3.9 MB/s eta 0:00:01     |████████████████▉               | 24.1 MB 3.5 MB/s eta 0:00:07
# ...
#      |████████████████████████████████| 1.3 MB 4.4 MB/s eta 0:00:01
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 207.1 MB 3.8 MB/s eta 0:00:01    |██████████████▍                 | 93.2 MB 3.6 MB/s eta 0:00:33
# ...
#      |████████████████████████████████| 463 kB 3.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.2 MB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 65 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 12.2 MB 5.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.6 MB 2.6 MB/s eta 0:00:01
# ...

# %%
from deepface import DeepFace
import cv2 #computer vision library to read image
import matplotlib.pyplot as plt
read_image=cv2.imread('/Users/anshu/Desktop/Photo on 23-12-21 at 2.54 PM.jpg')  #reading image
#plt.imshow(read_image)
plt.imshow(read_image[:,:,::-1])       ### img[::-1] ---> all items in the array reversed --> BGR to RGB
demography=DeepFace.analyze(read_image) #analyzing image
